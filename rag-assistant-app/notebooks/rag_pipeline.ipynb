# %% [markdown]
# # RAG Document Assistant - Pipeline Notebook
#
# **Domain:** Machine-learning study notes (6 PDF documents).
# **Goal:** clean and chunk the documents, embed them, store them in a persistent vector database, build a grounded RAG pipeline with a local Ollama LLM, and evaluate it. The persisted store is exported to `backend/data/vector_store/` and loaded directly by the FastAPI backend.
#
# **Languages:** English and Arabic. A multilingual embedding model lets an Arabic question find English passages (and the other way round), and the assistant answers in the language of the question.
#
# **Before running**
# 1. `ollama pull llama3.2` and make sure the Ollama app/server is running.
# 2. Run **Kernel -> Restart & Run All**. The notebook is re-runnable: the vector collection is rebuilt from scratch each time.
#
# **Sections:** 0 Setup - 2.1 Load & Inspect - 2.2 Chunking - 2.3 Embeddings & Vector Store - 2.4 Retrieval & Prompting - 2.5 Vision - 2.6 Evaluation - 2.7 Export

# %% [markdown]
# ## 0. Setup & configuration

# %%
import json
import os
import re
from pathlib import Path

import pandas as pd
from pypdf import PdfReader

# Works whether Jupyter is started from the project root or from notebooks/
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

RAW_DIR = ROOT / "data" / "raw"
STORE_DIR = ROOT / "backend" / "data" / "vector_store"   # folder loaded by the backend
CHROMA_DIR = STORE_DIR / "chroma_db"
STORE_DIR.mkdir(parents=True, exist_ok=True)

# ---- Configuration: one place, exported to config.json in section 2.7 ----
EMBEDDING_MODEL = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"   # English + Arabic + 50 more languages
COLLECTION_NAME = "documents"
CHUNK_SIZE = 800       # characters
CHUNK_OVERLAP = 100    # characters
TOP_K = 4              # chunks passed to the LLM
MIN_SIMILARITY = 0.25  # below this the assistant refuses instead of guessing
LLM_MODEL = os.environ.get("OLLAMA_MODEL", "llama3.2")   # set OLLAMA_MODEL in backend/.env to change it

print("Project root :", ROOT)
print("Raw data dir :", RAW_DIR)
print("Vector store :", STORE_DIR)
# Out:
# Project root : D:\ITI\rag-assistant-app
# Raw data dir : D:\ITI\rag-assistant-app\data\raw
# Vector store : D:\ITI\rag-assistant-app\backend\data\vector_store

# %% [markdown]
# ## 2.1 Load & Inspect

# %%
def clean_text(text: str) -> str:
    """Normalize text extracted from a PDF page."""
    text = re.sub(r"-\n(\w)", r"\1", text)   # re-join words hyphenated across lines
    text = re.sub(r"\s*\n\s*", " ", text)     # line breaks -> spaces
    text = re.sub(r"\s{2,}", " ", text)        # collapse repeated whitespace
    return text.strip()


pages, failed, needs_ocr = [], [], []
files = sorted(p for p in RAW_DIR.iterdir() if p.suffix.lower() in {".pdf", ".txt", ".md"})

for path in files:
    try:
        if path.suffix.lower() == ".pdf":
            reader = PdfReader(str(path))
            for page_no, page in enumerate(reader.pages, start=1):
                text = clean_text(page.extract_text() or "")
                if len(text) < 50:                      # almost no text -> probably a scan
                    needs_ocr.append(f"{path.name} (page {page_no})")
                    continue
                pages.append({"source": path.name, "page": page_no, "text": text})
        else:
            pages.append({"source": path.name, "page": 1, "text": clean_text(path.read_text(encoding="utf-8"))})
    except Exception as exc:
        failed.append((path.name, str(exc)))

inventory = (
    pd.DataFrame(pages)
    .groupby("source")
    .agg(pages=("page", "count"), characters=("text", lambda s: int(s.str.len().sum())))
)
display(inventory)
print(f"Files found      : {len(files)}  (formats: {sorted({p.suffix.lower() for p in files})})")
print(f"Pages extracted  : {len(pages)}")
print(f"Failed to parse  : {failed if failed else 'none'}")
print(f"Pages needing OCR: {needs_ocr if needs_ocr else 'none'}")
# Out:
#                                        pages  characters
# source
# 01_supervised_learning.pdf                 2        2382
# 02_unsupervised_learning.pdf               2        2553
# 03_model_evaluation.pdf                    1        2260
# 04_overfitting_and_regularization.pdf      1        2038
# 05_neural_networks_basics.pdf              1        2092
# 06_feature_engineering.pdf                 2        2149
# Files found      : 6  (formats: ['.pdf'])
# Pages extracted  : 9
# Failed to parse  : none
# Pages needing OCR: none

# %% [markdown]
# **Findings (for the provided sample corpus).** The corpus contains **6 PDF documents with 9 pages in total** (about 13,500 characters). All files are text-extractable, **no file failed to parse and no page needs OCR**. Cleaning needed: joining line breaks inside paragraphs and collapsing repeated whitespace. *If you replace the documents with your own, re-run this cell and update this paragraph with your numbers.*

# %% [markdown]
# ## 2.2 Chunking strategy

# %%
SENTENCE_ENDS = (". ", "? ", "! ")


def chunk_text(text: str, chunk_size: int = CHUNK_SIZE, overlap: int = CHUNK_OVERLAP) -> list[str]:
    """Fixed-size character chunks with overlap that prefer to end at a sentence boundary."""
    chunks, start, n = [], 0, len(text)
    while start < n:
        end = min(start + chunk_size, n)
        if end < n:
            window_start = start + int(chunk_size * 0.7)          # only look in the last 30 percent
            cut = max(text.rfind(t, window_start, end) for t in SENTENCE_ENDS)
            if cut != -1:
                end = cut + 1                                     # keep the punctuation mark
            else:
                space = text.rfind(" ", window_start, end)
                if space != -1:
                    end = space
        chunk = text[start:end].strip()
        if chunk:
            chunks.append(chunk)
        if end >= n:
            break
        next_start = max(end - overlap, start + 1)
        space = text.find(" ", next_start, end)                   # start the next chunk on a word boundary
        start = space + 1 if space != -1 else next_start
    return chunks


chunks = []
for page in pages:                     # chunk page by page so every chunk keeps an exact page number
    for i, piece in enumerate(chunk_text(page["text"])):
        chunks.append({
            "id": f"{Path(page['source']).stem}-p{page['page']}-c{i}",
            "source": page["source"],
            "page": page["page"],
            "text": piece,
        })

lengths = pd.Series([len(c["text"]) for c in chunks])
print(f"{len(chunks)} chunks | length min/mean/max = {lengths.min()} / {lengths.mean():.0f} / {lengths.max()} characters")
print("\nExample chunk:", chunks[1]["id"])
print(chunks[1]["text"])
# Out:
# 24 chunks | length min/mean/max = 119 / 622 / 799 characters
#
# Example chunk: 01_supervised_learning-p1-c1
# regression fits a straight line (or a hyperplane in higher dimensions) to predict a numeric target. Logistic regression is used for binary classification and outputs a probability between 0 and 1. Decision trees split the data with a sequence of if-else questions about the features. Random forests train many decision trees on random subsets of the data and features and then average or vote on their predictions, which reduces overfitting. k-Nearest Neighbors (k-NN) predicts using the labels of the k closest training examples. Support Vector Machines (SVM) find the decision boundary that maximizes the margin between classes. Loss functions Training a supervised model means minimizing a loss function that measures prediction error.

# %% [markdown]
# **Why 800 characters with 100 overlap?**
# - **~800 characters (about 150-200 words)** is large enough to contain a complete idea (a definition plus its example) but small enough that one chunk stays focused on one topic, which keeps the embedding precise. Much larger chunks blur several topics together; much smaller chunks split definitions from their explanations.
# - **100 characters (about 12 percent) overlap** prevents a sentence that falls on a boundary from being cut in half and lost from both chunks.
# - Chunks end at a **sentence boundary** when possible, and chunking is done **per page**, so every citation can point to an exact page.
# - With `TOP_K = 4`, the prompt receives about 3,200 characters of context, which fits comfortably in the small local model's context window.

# %% [markdown]
# ## 2.3 Embeddings & vector store

# %%
import chromadb
from sentence_transformers import SentenceTransformer

embedder = SentenceTransformer(EMBEDDING_MODEL)
texts = [c["text"] for c in chunks]
embeddings = embedder.encode(texts, batch_size=32, normalize_embeddings=True, show_progress_bar=True)
print("Embedding matrix:", embeddings.shape)

# Persistent Chroma database on disk (rebuilt from scratch on every run)
client = chromadb.PersistentClient(path=str(CHROMA_DIR))
try:
    client.delete_collection(COLLECTION_NAME)
except Exception:
    pass                                # collection did not exist yet
collection = client.create_collection(COLLECTION_NAME)   # default metric: squared L2 (cos = 1 - d/2 on unit vectors)
collection.add(
    ids=[c["id"] for c in chunks],
    embeddings=embeddings.tolist(),
    documents=texts,
    metadatas=[{"source": c["source"], "page": c["page"]} for c in chunks],
)
print("Chunks stored in Chroma:", collection.count())
print("Persisted at:", CHROMA_DIR)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Embedding matrix: (24, 384)
# Chunks stored in Chroma: 24
# Persisted at: D:\ITI\rag-assistant-app\backend\data\vector_store\chroma_db

# %% [markdown]
# **Choices.** `paraphrase-multilingual-MiniLM-L12-v2` is a compact (about 470 MB) sentence-embedding model that runs on CPU and maps more than 50 languages, including **Arabic**, into the same vector space. That is what lets an Arabic question retrieve English passages. Embeddings are **normalized**, so similarity is a plain cosine score. **Chroma** persists everything to disk, so the backend just opens the folder instead of rebuilding anything.

# %% [markdown]
# ## 2.4 Retrieval & prompting

# %%
def retrieve(question: str, k: int = TOP_K) -> list[dict]:
    """Return the k most similar chunks with a cosine-similarity score."""
    q = embedder.encode([question], normalize_embeddings=True).tolist()
    res = collection.query(query_embeddings=q, n_results=k, include=["documents", "metadatas", "distances"])
    return [
        {"text": doc, "source": meta["source"], "page": int(meta["page"]), "score": round(1 - dist / 2, 4)}
        for doc, meta, dist in zip(res["documents"][0], res["metadatas"][0], res["distances"][0])
    ]


TEST_SET = [
    {"question": "What is the difference between classification and regression?",
     "expected_source": "01_supervised_learning.pdf", "keywords": ["continuous", "discrete", "category"]},
    {"question": "How does the elbow method help choose k in k-means?",
     "expected_source": "02_unsupervised_learning.pdf", "keywords": ["within-cluster", "inertia", "sum of squares"]},
    {"question": "What advantage does DBSCAN have over k-means?",
     "expected_source": "02_unsupervised_learning.pdf", "keywords": ["arbitrary shape", "number of clusters", "noise"]},
    {"question": "What is the F1 score?",
     "expected_source": "03_model_evaluation.pdf", "keywords": ["harmonic mean"]},
    {"question": "Why is accuracy misleading on imbalanced datasets?",
     "expected_source": "03_model_evaluation.pdf", "keywords": ["majority", "99", "always predict"]},
    {"question": "What is the difference between L1 and L2 regularization?",
     "expected_source": "04_overfitting_and_regularization.pdf", "keywords": ["sparse", "exactly zero", "squared"]},
    {"question": "What dropout rates are typical?",
     "expected_source": "04_overfitting_and_regularization.pdf", "keywords": ["0.2", "0.5"]},
    {"question": "What does the ReLU activation function do?",
     "expected_source": "05_neural_networks_basics.pdf", "keywords": ["max(0", "zero", "negative"]},
    {"question": "What is data leakage and how can I avoid it when scaling features?",
     "expected_source": "06_feature_engineering.pdf", "keywords": ["training set", "split"]},
    {"question": "How should a categorical feature such as color be encoded?",
     "expected_source": "06_feature_engineering.pdf", "keywords": ["one-hot"]},
    # Arabic questions about the English documents (cross-lingual retrieval; the answer must be in Arabic)
    {"question": "ما هو مقياس F1؟",
     "expected_source": "03_model_evaluation.pdf", "keywords": ["التوافقي", "harmonic", "الاسترجاع", "recall"]},
    {"question": "ما الفرق بين التصنيف والانحدار؟",
     "expected_source": "01_supervised_learning.pdf", "keywords": ["مستمر", "متصل", "رقمي", "فئة", "continuous"]},
    {"question": "ما الفرق بين التنظيم L1 وL2؟",
     "expected_source": "04_overfitting_and_regularization.pdf", "keywords": ["صفر", "متناثر", "مربع", "sparse", "squared"]},
    {"question": "ما هو تسرب البيانات وكيف أتجنبه؟",
     "expected_source": "06_feature_engineering.pdf", "keywords": ["التدريب", "تقسيم", "training", "split"]},
    # Out-of-scope questions: the assistant must refuse instead of answering from its own knowledge
    {"question": "Who won the 2018 FIFA World Cup?", "expected_source": None, "keywords": []},
    {"question": "What is the capital of Australia?", "expected_source": None, "keywords": []},
    {"question": "من فاز بكأس العالم 2018؟", "expected_source": None, "keywords": []},   # Arabic, out of scope
]

rows = []
for t in TEST_SET:
    hits = retrieve(t["question"])
    top = hits[0]
    in_scope = t["expected_source"] is not None
    rows.append({
        "question": t["question"],
        "top_source": f"{top['source']} (p.{top['page']})",
        "top_score": top["score"],
        "expected": t["expected_source"] or "(out of scope)",
        "relevant_in_top_k": (t["expected_source"] in {h["source"] for h in hits}) if in_scope else None,
        "would_be_refused": top["score"] < MIN_SIMILARITY,
    })
retrieval_df = pd.DataFrame(rows)
pd.set_option("display.max_colwidth", 70)
display(retrieval_df)
print("Relevant source in top-k:", int(retrieval_df["relevant_in_top_k"].dropna().sum()), "/", int(retrieval_df["relevant_in_top_k"].notna().sum()))
print("Check the top_score of the out-of-scope questions and tune MIN_SIMILARITY if needed.")
# Out:
#                                                               question  \
# 0        What is the difference between classification and regression?
# 1                  How does the elbow method help choose k in k-means?
# 2                        What advantage does DBSCAN have over k-means?
# 3                                                What is the F1 score?
# 4                   Why is accuracy misleading on imbalanced datasets?
# 5             What is the difference between L1 and L2 regularization?
# 6                                      What dropout rates are typical?
# 7                           What does the ReLU activation function do?
# 8   What is data leakage and how can I avoid it when scaling features?
# 9           How should a categorical feature such as color be encoded?
# 10                                                     ما هو مقياس F1؟
# 11                                     ما الفرق بين التصنيف والانحدار؟
# 12                                        ما الفرق بين التنظيم L1 وL2؟
# 13                                    ما هو تسرب البيانات وكيف أتجنبه؟
# 14                                    Who won the 2018 FIFA World Cup?
# 15                                   What is the capital of Australia?
# 16                                            من فاز بكأس العالم 2018؟
#
#                                      top_source  top_score  \
# 0              01_supervised_learning.pdf (p.1)     0.6178
# 1            02_unsupervised_learning.pdf (p.1)     0.5956
# 2            02_unsupervised_learning.pdf (p.1)     0.5940
# 3                 03_model_evaluation.pdf (p.1)     0.4821
# 4                 03_model_evaluation.pdf (p.1)     0.6493
# 5              06_feature_engineering.pdf (p.2)     0.3994
# 6   04_overfitting_and_regularization.pdf (p.1)     0.6618
# 7           05_neural_networks_basics.pdf (p.1)     0.3666
# 8              06_feature_engineering.pdf (p.1)     0.6650
# 9              06_feature_engineering.pdf (p.1)     0.4153
# 10                03_model_evaluation.pdf (p.1)     0.3688
# 11             06_feature_engineering.pdf (p.1)     0.4405
# 12           02_unsupervised_learning.pdf (p.1)     0.3368
# 13             06_feature_engineering.pdf (p.1)     0.5232
# 14                03_model_evaluation.pdf (p.1)     0.1646
# 15                03_model_evaluation.pdf (p.1)     0.1249
# 16                03_model_evaluation.pdf (p.1)     0.2018
#
#                                  expected relevant_in_top_k  would_be_refused
# 0              01_supervised_learning.pdf              True             False
# 1            02_unsupervised_learning.pdf              True             False
# 2            02_unsupervised_learning.pdf              True             False
# 3                 03_model_evaluation.pdf              True             False
# 4                 03_model_evaluation.pdf              True             False
# 5   04_overfitting_and_regularization.pdf              True             False
# 6   04_overfitting_and_regularization.pdf              True             False
# 7           05_neural_networks_basics.pdf              True             False
# 8              06_feature_engineering.pdf              True             False
# 9              06_feature_engineering.pdf              True             False
# 10                03_model_evaluation.pdf              True             False
# 11             01_supervised_learning.pdf              True             False
# 12  04_overfitting_and_regularization.pdf             False             False
# 13             06_feature_engineering.pdf              True             False
# 14                         (out of scope)              None              True
# 15                         (out of scope)              None              True
# 16                         (out of scope)              None              True
# Relevant source in top-k: 13 / 14
# Check the top_score of the out-of-scope questions and tune MIN_SIMILARITY if needed.

# %% [markdown]
# ### 2.4b Hybrid retrieval: dense + BM25
#
# Dense embeddings capture meaning but can miss exact terms (names, acronyms, numbers); BM25 does the opposite. The backend therefore takes the top dense candidates, scores them with **BM25**, and merges the two rankings with **Reciprocal Rank Fusion (RRF)**: `score(d) = sum of 1 / (60 + rank(d))` over both rankings. RRF needs no score calibration, which is why it is a robust default. The BM25 and RRF code is imported from the backend, so the notebook and the API use exactly the same implementation.

# %%
import sys

sys.path.insert(0, str(ROOT / "backend"))
from app.services.bm25 import BM25Index, fuse_rankings   # same code the API uses

bm25 = BM25Index([c["id"] for c in chunks], [c["text"] for c in chunks])


def retrieve_hybrid(question: str, k: int = TOP_K, min_score: float = 0.0, n_candidates: int = 12) -> list[dict]:
    """Dense candidates re-ranked with BM25 via RRF; chunks below min_score are dropped."""
    q = embedder.encode([question], normalize_embeddings=True).tolist()
    res = collection.query(query_embeddings=q, n_results=min(n_candidates, collection.count()),
                           include=["documents", "metadatas", "distances"])
    ids = list(res["ids"][0])
    candidates = {
        i: {"text": doc, "source": meta["source"], "page": int(meta["page"]), "score": round(1 - dist / 2, 4)}
        for i, doc, meta, dist in zip(ids, res["documents"][0], res["metadatas"][0], res["distances"][0])
    }
    lexical = bm25.scores(question)
    lexical_rank = sorted((i for i in ids if lexical.get(i, 0) > 0), key=lambda i: lexical[i], reverse=True)
    fused = fuse_rankings([ids, lexical_rank])
    ordered = sorted(ids, key=lambda i: fused[i], reverse=True)
    return [candidates[i] for i in ordered if candidates[i]["score"] >= min_score][:k]


def evaluate_retrieval(fn) -> dict:
    """Hit@k = expected document in the top k; MRR = mean reciprocal rank of the expected document."""
    scoped = [t for t in TEST_SET if t["expected_source"]]
    hits, reciprocal_ranks = 0, []
    for t in scoped:
        sources = [c["source"] for c in fn(t["question"])]
        found = t["expected_source"] in sources
        hits += found
        reciprocal_ranks.append(1 / (sources.index(t["expected_source"]) + 1) if found else 0.0)
    return {"Hit@k": hits / len(scoped), "MRR": sum(reciprocal_ranks) / len(scoped)}


comparison = pd.DataFrame({
    "dense only": evaluate_retrieval(retrieve),
    "hybrid (dense + BM25 + RRF)": evaluate_retrieval(retrieve_hybrid),
}).T
display(comparison.round(3))
# Out:
#                              Hit@k    MRR
# dense only                   0.929  0.821
# hybrid (dense + BM25 + RRF)  1.000  0.875

# %% [markdown]
# **Reading the table.** *Hit@k* asks whether the expected document is among the top-k results; *MRR* also rewards ranking it first. On a small, clean corpus both methods score high, so the gap is small; hybrid retrieval matters most on larger corpora with exact terms such as acronyms, product codes or names. *After running, replace this note with your own numbers and one sentence of interpretation.*

# %%
from app.services.language import is_refusal, refusal_for            # same helpers the API uses
from app.services.prompts import build_messages as build_prompt      # same prompts the API uses


def build_messages(question: str, hits: list[dict]) -> list[dict]:
    context = "\n\n".join(
        f"[{i}] (source: {h['source']}, page {h['page']})\n{h['text']}" for i, h in enumerate(hits, 1)
    )
    return build_prompt(question, context)


def extract_citations(answer: str, n_chunks: int) -> list[int]:
    numbers = set()
    for group in re.findall(r"\[([\d,\s]+)\]", answer):
        for part in group.split(","):
            if part.strip().isdigit() and 1 <= int(part) <= n_chunks:
                numbers.add(int(part))
    return sorted(numbers)


import ollama


def ask(question: str, k: int = TOP_K, min_score: float = MIN_SIMILARITY) -> dict:
    """Full RAG: retrieve -> (refuse if nothing relevant) -> prompt -> generate -> cite."""
    hits = retrieve_hybrid(question, k, min_score=min_score)
    if not hits:
        return {"answer": refusal_for(question), "sources": [], "hits": []}   # refusal in the question's language
    response = ollama.chat(model=LLM_MODEL, messages=build_messages(question, hits), options={"temperature": 0.1})
    answer = response["message"]["content"].strip()
    if is_refusal(answer):
        return {"answer": answer, "sources": [], "hits": hits}
    used = [hits[i - 1] for i in extract_citations(answer, len(hits))] or hits
    sources = list(dict.fromkeys(f"{h['source']} (page {h['page']})" for h in used))
    return {"answer": answer, "sources": sources, "hits": hits}


for demo_question in ("What is the F1 score?", "ما هو مقياس F1؟"):
    demo = ask(demo_question)
    print("Q:", demo_question, "\nA:", demo["answer"], "\nSources:", demo["sources"], "\n")
# Out:
# Q: What is the F1 score?
# A: The F1 score is the harmonic mean of precision and recall, computed as 2PR divided by (P + R). [1]
# Sources: ['03_model_evaluation.pdf (page 1)']
# Q: ما هو مقياس F1؟
# A: مقياس F1 هو المعدل الم Harmony من دقة و تعرف على كتلة 2PR / (P + R) [1].
# Sources: ['03_model_evaluation.pdf (page 1)']

# %% [markdown]
# **Grounding design.** Hybrid retrieval finds the right passages; then three layers keep the assistant from answering out of its own memory: (1) the prompt says to use *only* the numbered passages and to reply with a fixed refusal sentence otherwise, (2) a **similarity threshold** skips the LLM entirely when nothing relevant is retrieved, and (3) a low **temperature (0.1)** reduces creative drift. Citations are the passage numbers `[n]` produced by the model, mapped back to `file (page n)` in code.

# %% [markdown]
# ## 2.5 Vision component
#
# Not applicable: this project follows the **Core Track** (text-only RAG). No image dataset or YOLO model is used.

# %% [markdown]
# ## 2.6 Evaluation

# %%
records = []
for t in TEST_SET:
    result = ask(t["question"])
    answer = result["answer"]
    in_scope = t["expected_source"] is not None
    refused = is_refusal(answer)
    retrieved = {h["source"] for h in result["hits"]}

    if in_scope:
        relevant = t["expected_source"] in retrieved
        cites_expected = any(s.startswith(t["expected_source"]) for s in result["sources"])
        has_keyword = any(k.lower() in answer.lower() for k in t["keywords"])
        verdict = "correct" if (relevant and cites_expected and has_keyword and not refused) else "check manually"
    else:
        relevant = None
        verdict = "correct (refused)" if refused else "hallucinated?"

    records.append({
        "question": t["question"],
        "retrieved_source": ", ".join(sorted(retrieved)) or "-",
        "context_relevant": relevant,
        "answer": answer,
        "cited_sources": "; ".join(result["sources"]) or "-",
        "auto_verdict": verdict,
    })

results_df = pd.DataFrame(records)
pd.set_option("display.max_colwidth", 120)
display(results_df[["question", "retrieved_source", "context_relevant", "cited_sources", "auto_verdict"]])
results_df.to_csv(ROOT / "notebooks" / "evaluation_results.csv", index=False)

n_ok = results_df["auto_verdict"].str.startswith("correct").sum()
print(f"Auto-verdict correct: {n_ok} / {len(results_df)}  (read the full answers below and confirm by hand)")
for r in records:
    print("\nQ:", r["question"], "\nA:", r["answer"], "\nSources:", r["cited_sources"], "| verdict:", r["auto_verdict"])
# Out:
#                                                               question  \
# 0        What is the difference between classification and regression?
# 1                  How does the elbow method help choose k in k-means?
# 2                        What advantage does DBSCAN have over k-means?
# 3                                                What is the F1 score?
# 4                   Why is accuracy misleading on imbalanced datasets?
# 5             What is the difference between L1 and L2 regularization?
# 6                                      What dropout rates are typical?
# 7                           What does the ReLU activation function do?
# 8   What is data leakage and how can I avoid it when scaling features?
# 9           How should a categorical feature such as color be encoded?
# 10                                                     ما هو مقياس F1؟
# 11                                     ما الفرق بين التصنيف والانحدار؟
# 12                                        ما الفرق بين التنظيم L1 وL2؟
# 13                                    ما هو تسرب البيانات وكيف أتجنبه؟
# 14                                    Who won the 2018 FIFA World Cup?
# 15                                   What is the capital of Australia?
# 16                                            من فاز بكأس العالم 2018؟
#
#                                                                                                            retrieved_source  \
# 0                                                         01_supervised_learning.pdf, 04_overfitting_and_regularization.pdf
# 1                                                                  02_unsupervised_learning.pdf, 06_feature_engineering.pdf
# 2                                                                  02_unsupervised_learning.pdf, 06_feature_engineering.pdf
# 3                                                            03_model_evaluation.pdf, 04_overfitting_and_regularization.pdf
# 4                                                            03_model_evaluation.pdf, 04_overfitting_and_regularization.pdf
# 5                                                         04_overfitting_and_regularization.pdf, 06_feature_engineering.pdf
# 6                                01_supervised_learning.pdf, 03_model_evaluation.pdf, 04_overfitting_and_regularization.pdf
# 7                                                                                             05_neural_networks_basics.pdf
# 8                                                         04_overfitting_and_regularization.pdf, 06_feature_engineering.pdf
# 9                                                                                                06_feature_engineering.pdf
# 10                                        02_unsupervised_learning.pdf, 03_model_evaluation.pdf, 06_feature_engineering.pdf
# 11                                                                   01_supervised_learning.pdf, 06_feature_engineering.pdf
# 12  01_supervised_learning.pdf, 02_unsupervised_learning.pdf, 04_overfitting_and_regularization.pdf, 06_feature_engineer...
# 13  02_unsupervised_learning.pdf, 04_overfitting_and_regularization.pdf, 05_neural_networks_basics.pdf, 06_feature_engin...
# 14                                                                                                                        -
# 15                                                                                                                        -
# 16                                                                                                                        -
#
#    context_relevant                                   cited_sources  \
# 0              True             01_supervised_learning.pdf (page 1)
# 1              True           02_unsupervised_learning.pdf (page 1)
# 2              True           02_unsupervised_learning.pdf (page 1)
# 3              True                03_model_evaluation.pdf (page 1)
# 4              True                03_model_evaluation.pdf (page 1)
# 5              True  04_overfitting_and_regularization.pdf (page 1)
# 6              True  04_overfitting_and_regularization.pdf (page 1)
# 7              True          05_neural_networks_basics.pdf (page 1)
# 8              True             06_feature_engineering.pdf (page 1)
# 9              True             06_feature_engineering.pdf (page 1)
# 10             True                03_model_evaluation.pdf (page 1)
# 11             True                                               -
# 12             True  04_overfitting_and_regularization.pdf (page 1)
# 13             True             06_feature_engineering.pdf (page 1)
# 14             None                                               -
# 15             None                                               -
# 16             None                                               -
#
#          auto_verdict
# 0             correct
# 1             correct
# 2             correct
# 3             correct
# 4             correct
# 5             correct
# 6             correct
# 7             correct
# 8             correct
# 9             correct
# 10     check manually
# 11     check manually
# 12            correct
# 13            correct
# 14  correct (refused)
# 15  correct (refused)
# 16  correct (refused)
# Auto-verdict correct: 15 / 17  (read the full answers below and confirm by hand)
#
# Q: What is the difference between classification and regression?
# A: Classification predicts a discrete category, whereas regression predicts a continuous numeric value. Both use labeled data, but the type of target the model has to predict differs between them. [3] [1]
# Sources: 01_supervised_learning.pdf (page 1) | verdict: correct
#
# Q: How does the elbow method help choose k in k-means?
# A: The elbow method helps choose k in k-means by plotting the within-cluster sum of squares (also called inertia) against k. The best k is the point where the curve bends like an elbow and the improvement slows down sharply. [1] This is because the inertia curve has a characteristic "elbow" shape, where the rate of decrease in inertia slows down as k increases. [1]
# Sources: 02_unsupervised_learning.pdf (page 1) | verdict: correct
#
# Q: What advantage does DBSCAN have over k-means?
# A: DBSCAN has the advantage that it does not need the number of clusters in advance, whereas k-means requires the number of clusters to be fixed in advance. [1] Additionally, DBSCAN can find clusters of arbitrary shape, whereas k-means assumes clusters that are roughly spherical and of similar size. [1][4]
# Sources: 02_unsupervised_learning.pdf (page 1) | verdict: correct
#
# Q: What is the F1 score?
# A: The F1 score is the harmonic mean of precision and recall, computed as 2PR divided by (P + R). [1]
# Sources: 03_model_evaluation.pdf (page 1) | verdict: correct
#
# Q: Why is accuracy misleading on imbalanced datasets?
# A: Accuracy can be misleading on imbalanced datasets because it can be very high even if the model is not performing well. For example, if 99 percent of transactions are legitimate, a model that always predicts the majority class, legitimate, can reach 99 percent accuracy while catching no fraud at all. This is because accuracy is calculated as the number of correct predictions divided by the total number of predictions, and in an imbalanced dataset, the majority class often has a large number of instances. [1]
# Sources: 03_model_evaluation.pdf (page 1) | verdict: correct
#
# Q: What is the difference between L1 and L2 regularization?
# A: L1 regularization penalizes the sum of the absolute values of the weights, while L2 regularization penalizes the sum of the squared weights. L1 regularization can push some weights to exactly zero, producing sparse models and working as automatic feature selection, whereas L2 regularization rarely makes weights exactly zero, shrinking them toward zero instead. [2] [3]
# Sources: 04_overfitting_and_regularization.pdf (page 1) | verdict: correct
#
# Q: What dropout rates are typical?
# A: Typical dropout rates for neural networks are between 0.2 and 0.5 [1].
# Sources: 04_overfitting_and_regularization.pdf (page 1) | verdict: correct
#
# Q: What does the ReLU activation function do?
# A: The ReLU activation function returns zero for negative inputs and the input itself for positive inputs. It is cheap to compute, helps against vanishing gradients, and is the default choice for hidden layers. [1]
# Sources: 05_neural_networks_basics.pdf (page 1) | verdict: correct
#
# Q: What is data leakage and how can I avoid it when scaling features?
# A: Data leakage occurs when information from the validation or test data leaks into training, resulting in over-optimistic results. To avoid data leakage when scaling features, split the data first, fit every transformer on the training set only, and then apply it to the validation and test sets. This can be easily done using Scikit-learn Pipelines. [1][2]
# Sources: 06_feature_engineering.pdf (page 1) | verdict: correct
#
# Q: How should a categorical feature such as color be encoded?
# A: One-hot encoding creates one binary column for each category. For example, a color feature with the values red, green and blue becomes three columns. [1][2]
# Sources: 06_feature_engineering.pdf (page 1) | verdict: correct
#
# Q: ما هو مقياس F1؟
# A: مقياس F1 هو المعدل الحارم من دقة و تعرف علىه ك 2 دقة / (دقة + تعرف). [1]
# Sources: 03_model_evaluation.pdf (page 1) | verdict: check manually
#
# Q: ما الفرق بين التصنيف والانحدار؟
# A: لا تتوفر لدي معلومات كافية في المستندات المقدمة للإجابة عن هذا السؤال.
# Sources: - | verdict: check manually
#
# Q: ما الفرق بين التنظيم L1 وL2؟
# A: الفرق بين التنظيم L1 وL2 هو أن التنظيم L1 يضمن أن بعض الأوزان تكون صفرة، بينما التنظيم L2 يضمن أن الأوزان تقل إلى الصفر ولكن لا تكون exactly صفرة. [2] التنظيم L1 يُستخدم في الحالة التي تريد automatic feature selection، بينما التنظيم L2 يُستخدم في الحالة التي تريد shrinkage of weights but لا تريد automatic feature selection. [2]
# Sources: 04_overfitting_and_regularization.pdf (page 1) | verdict: correct
#
# Q: ما هو تسرب البيانات وكيف أتجنبه؟
# A: تسرب البيانات هو حدث يحدث عندما ينتقل المعلومات من البيانات التدريبية إلى البيانات التحليلية أو التحقق، مما يؤدي إلى نتائج مُتوقعة. [1] لمنع التسرب، يجب علىك تقسيم البيانات أولًا، ثم تطبيق كل معالج على مجموعة التدريب فقط، وبالتالي تطبيقها على مجموعة التحقق والتحقق. [1] يمكن استخدام Sklearn Pipelines لتحقيق هذا.
# Sources: 06_feature_engineering.pdf (page 1) | verdict: correct
#
# Q: Who won the 2018 FIFA World Cup?
# A: I don't have enough information in the provided documents to answer that.
# Sources: - | verdict: correct (refused)
#
# Q: What is the capital of Australia?
# A: I don't have enough information in the provided documents to answer that.
# Sources: - | verdict: correct (refused)
#
# Q: من فاز بكأس العالم 2018؟
# A: لا تتوفر لدي معلومات كافية في المستندات المقدمة للإجابة عن هذا السؤال.
# Sources: - | verdict: correct (refused)

# %% [markdown]
# ### Failure analysis *(complete this cell after running the notebook)*
#
# The automatic verdict only checks: relevant source retrieved, that source cited, an expected keyword present, and refusal on out-of-scope questions. **Read every answer and correct the verdicts by hand**, then replace this cell with your own observations. Things worth looking for:
#
# - **Topic overlap between documents** (e.g. L1 regularization appears in both the regularization and the feature-engineering notes): does the right document rank first?
# - **Weak citations:** does the small model forget the `[n]` markers or cite the wrong passage?
# - **Out-of-scope questions:** were they refused, or did the model answer from its own knowledge? If a refusal was missed, raise `MIN_SIMILARITY`.
#
# **Mitigations already built in:** strict "context only" system prompt, fixed refusal sentence, similarity threshold, temperature 0.1, and per-page chunks for precise citations.

# %% [markdown]
# ## 2.7 Export for the backend

# %%
config = {
    "embedding_model": EMBEDDING_MODEL,
    "collection_name": COLLECTION_NAME,
    "chunk_size": CHUNK_SIZE,
    "chunk_overlap": CHUNK_OVERLAP,
    "similarity": "squared L2 on normalized embeddings (cosine = 1 - d/2)",
    "num_chunks": collection.count(),
    "source_files": sorted({c["source"] for c in chunks}),
    "recommended_top_k": TOP_K,
    "recommended_min_similarity": MIN_SIMILARITY,
    "recommended_llm": LLM_MODEL,
}
(STORE_DIR / "config.json").write_text(json.dumps(config, indent=2), encoding="utf-8")

# Verify exactly like the backend does: open the persisted store from disk
reopened = chromadb.PersistentClient(path=str(CHROMA_DIR)).get_collection(COLLECTION_NAME)
assert reopened.count() == len(chunks), "persisted store does not match the notebook state"
print("Exported to:", STORE_DIR)
print(json.dumps(config, indent=2))
# Out:
# Exported to: D:\ITI\rag-assistant-app\backend\data\vector_store
# {
#   "embedding_model": "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2",
#   "collection_name": "documents",
#   "chunk_size": 800,
#   "chunk_overlap": 100,
#   "similarity": "squared L2 on normalized embeddings (cosine = 1 - d/2)",
#   "num_chunks": 24,
#   "source_files": [
#     "01_supervised_learning.pdf",
#     "02_unsupervised_learning.pdf",
#     "03_model_evaluation.pdf",
#     "04_overfitting_and_regularization.pdf",
#     "05_neural_networks_basics.pdf",
#     "06_feature_engineering.pdf"
#   ],
#   "recommended_top_k": 4,
#   "recommended_min_similarity": 0.25,
#   "recommended_llm": "llama3.2"
# }
